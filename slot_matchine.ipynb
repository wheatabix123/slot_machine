# %%
# slot machine like at school
import time,os
import random as rand
from IPython.display import clear_output
start_time = time.time()
os.system('clear')
credits = 5
play_count = 0
hacker_time = rand.randint(5,30)
name = input ('what is your name? :')
print('Lets!')
time.sleep(1)
print('Go!')
time.sleep(1)
print('Gambling!!')
while credits > 0 :
  input('Press ENTER to gamble!: ')
  play_count = play_count + 1
  credits = credits - 1
  num1 = rand.randint(1,10)
  num2 = rand.randint(1,10)
  num3 = rand.randint(1,10)
  print('Spinning...')
  time.sleep(1)
  print(num1)
  time.sleep(1)
  print(num2)
  time.sleep(1)
  print(num3)
  time.sleep(1)
  if play_count == hacker_time:
    print('Uh Oh, You got hacked and lost all your credits!')
    time.sleep(3)
    clear_output()
    break
  elif num1 == 7 and num2 == 7 and num3 == 7:
    print('Super jackpot!!!')
    credits = credits + 1000
    print('You got 1000 credits!!')
    time.sleep(5)
    clear_output()

  elif num1 == num2 or num1 == num3 or num2 == num3:
    print('You matched two, take some credits, I guess?')
    print('You get 10 credits!')
    credits = credits + 10
    time.sleep(5)
    clear_output()
  elif num1 == num2 == num3:
    print('Jackpot!!')
    print('you get 100 credits')
    credits = credits + 100
    time.sleep(5)
    clear_output()
  elif num1 == 7 or num2 == 7 or num3 ==7:
    print('You got a 7!')
    print('you get 3 credits!')
    credits = credits + 3
    time.sleep(5)
    clear_output()
  else:
    print('No matches, sucks to suck.')
    print('you got nothing')
    time.sleep(5)
    clear_output()
  y_n = input('Would you like to gamble again? (y,n): ')
  if y_n == 'n':
    print('Play again soon, goodbye!')
    end_time = time.time()
    seconds = end_time - start_time
    rounded_seconds = round(seconds)
    print(f'You gambled {play_count} times!')
    print(f'You wasted {rounded_seconds} seconds playing this game!')
    time.sleep(10)
    clear_output()
    break
if credits == 0:
  end_time = time.time()
  seconds = end_time - start_time
  rounded_seconds = round(seconds)
  print('You are out of credits!')
  print(f'You gambled {play_count} times!')
  print(f'You wasted {rounded_seconds} seconds playing this game!')
  time.sleep(10)
  clear_output()
